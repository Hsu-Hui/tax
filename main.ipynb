# %%
#pip install tabula-py
import tabula
import pandas as pd
from os import listdir

# %%
inputpath = "./data/pdf/3/"
outpath = "./data/csv/3/"
files = listdir(inputpath)

# %%
for file in files:
    tabula.convert_into(inputpath + file, outpath + file.replace('pdf','csv'), output_format = 'csv',pages='all')
    print(file+'  finsh')
# Out:
# 109_101-1.pdf  finsh
# 109_101-2.pdf  finsh
# 109_101-3-0.pdf  finsh
# 109_101-3-1.pdf  finsh
# 109_101-3-2.pdf  finsh
# 109_102-1.pdf  finsh
# 109_102-2.pdf  finsh
# 109_102-2A-A.pdf  finsh
# 109_102-2A-B.pdf  finsh
# 109_102-2A-C.pdf  finsh
# 109_102-2A-D.pdf  finsh
# 109_102-2A-E.pdf  finsh
# 109_102-2A-F.pdf  finsh
# 109_102-2A-G.pdf  finsh
# 109_102-2A-H.pdf  finsh
# 109_102-2A-I.pdf  finsh
# 109_102-2A-J.pdf  finsh
# 109_102-2A-K.pdf  finsh
# 109_102-2A-M.pdf  finsh
# 109_102-2A-N.pdf  finsh
# 109_102-2A-O.pdf  finsh
# 109_102-2A-P.pdf  finsh
# 109_102-2A-Q.pdf  finsh
# 109_102-2A-T.pdf  finsh
# 109_102-2A-U.pdf  finsh
# 109_102-2A-V.pdf  finsh
# 109_102-2A-W.pdf  finsh
# 109_102-2A-X.pdf  finsh
# 109_102-2A-Z.pdf  finsh
# 109_102-3-0.pdf  finsh
# 109_102-3-1.pdf  finsh
# 109_102-3-2.pdf  finsh
# 109_103-1.pdf  finsh
# 109_103-2.pdf  finsh
# 109_103-3-0.pdf  finsh
# 109_103-3-1.pdf  finsh
# 109_103-3-2.pdf  finsh
# 109_104-1.pdf  finsh
# 109_104-2.pdf  finsh
# ...
